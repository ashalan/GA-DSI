# %% [markdown]
# # SQL Lab
#
# In this lab we will learn how to use execute SQL from the ipython notebook and practice some queries on the [Northwind sample database](https://northwinddatabase.codeplex.com/) that we used in Lesson 3.1.
#
# You can access the data with this command:
#
#     psql -h dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com -p 5432 -U dsi_student northwind
#     password: gastudents

# %% [markdown]
# First of all let's install the ipython-sql extension. You can find instructions [here](https://github.com/catherinedevlin/ipython-sql).

# %%
# !pip install ipython-sql

# %% [markdown]
# Let's see if it works:

# %%
# %load_ext sql

# %%
# %%sql postgresql://dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
#
# select * from orders limit 5;
# Out:
# 5 rows affected.
# [(10248, u'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, u'Vins et alcools Chevalier', u"59 rue de l'Abbaye", u'Reims', None, u'51100', u'France'),
#  (10249, u'TOMSP', 6, datetime.date(1996, 7, 5), datetime.date(1996, 8, 16), datetime.date(1996, 7, 10), 1, 11.61, u'Toms Spezialit\xe4ten', u'Luisenstr. 48', u'M\xfcnster', None, u'44087', u'Germany'),
#  (10250, u'HANAR', 4, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 12), 2, 65.83, u'Hanari Carnes', u'Rua do Pa\xe7o, 67', u'Rio de Janeiro', u'RJ', u'05454-876', u'Brazil'),
#  (10251, u'VICTE', 3, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 15), 1, 41.34, u'Victuailles en stock', u'2, rue du Commerce', u'Lyon', None, u'69004', u'France'),
#  (10252, u'SUPRD', 4, datetime.date(1996, 7, 9), datetime.date(1996, 8, 6), datetime.date(1996, 7, 11), 2, 51.3, u'Supr\xeames d\xe9lices', u'Boulevard Tirou, 255', u'Charleroi', None, u'B-6000', u'Belgium')]

# %% [markdown]
# If this isn't working, then it's back to psql for now...

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1: Inspect the database
#
# If we were connected via console, it would be easy to list all tables using `\dt`. We can however access table information performing a query on the `information_schema.tables` table.
#
# ### 1.a: List Tables
#
# 1. write a `SELECT` statement that lists all the tables in the public schema of the `northwind` database, sorted alphabetically

# %%
# %%sql
# SELECT table_schema,table_name
# FROM information_schema.tables
# WHERE table_schema = 'public'
# ORDER BY table_name
# Out:
# 19 rows affected.
# [(u'public', u'categories'),
#  (u'public', u'categoriesmerged'),
#  (u'public', u'customercustomerdemo'),
#  (u'public', u'customerdemographics'),
#  (u'public', u'customers'),
#  (u'public', u'employees'),
#  (u'public', u'employeeterritories'),
#  (u'public', u'movies'),
#  (u'public', u'order_details'),
#  (u'public', u'orders'),
#  (u'public', u'products'),
#  (u'public', u'ratings'),
#  (u'public', u'region'),
#  (u'public', u'shippers'),
#  (u'public', u'shippers_tmp'),
#  (u'public', u'suppliers'),
#  (u'public', u'table1'),
#  (u'public', u'territories'),
#  (u'public', u'usstates')]

# %% [markdown]
# ### 1.b: Print Schemas
#
# The table `INFORMATION_SCHEMA.COLUMNS` contains schema information on each.
#
# Query it to display schemas of all the public tables. In particular we are interested in the column names and data types. Make sure you only include public schemas to avoid cluttering your results with a bunch of postgres related stuff.

# %%
# %%sql
# SELECT column_name, data_type
# FROM information_schema.COLUMNS
# WHERE table_schema = 'public'
# ORDER BY table_name
# Out:
# 128 rows affected.
# [(u'Picture', u'bytea'),
#  (u'CategoryName', u'character varying'),
#  (u'CategoryID', u'smallint'),
#  (u'Description', u'text'),
#  (u'Description', u'text'),
#  (u'UnitsOnOrder', u'bigint'),
#  (u'Discontinued', u'bigint'),
#  (u'CategoryName', u'text'),
#  (u'Picture', u'text'),
#  (u'ReorderLevel', u'bigint'),
#  (u'ProductID', u'bigint'),
#  (u'index', u'bigint'),
#  (u'ProductName', u'text'),
#  (u'SupplierID', u'bigint'),
#  (u'CategoryID', u'bigint'),
#  (u'QuantityPerUnit', u'text'),
#  (u'UnitPrice', u'double precision'),
#  (u'UnitsInStock', u'bigint'),
#  (u'CustomerID', u'character'),
#  (u'CustomerTypeID', u'character'),
#  (u'CustomerTypeID', u'character'),
#  (u'CustomerDesc', u'text'),
#  (u'ContactName', u'character varying'),
#  (u'ContactTitle', u'character varying'),
#  (u'Address', u'character varying'),
#  (u'City', u'character varying'),
#  (u'Region', u'character varying'),
#  (u'PostalCode', u'character varying'),
#  (u'Country', u'character varying'),
#  (u'Phone', u'character varying'),
#  (u'Fax', u'character varying'),
#  (u'CustomerID', u'character'),
#  (u'CompanyName', u'character varying'),
#  (u'PostalCode', u'character varying'),
#  (u'Country', u'character varying'),
#  (u'ReportsTo', u'smallint'),
#  (u'PhotoPath', u'character varying'),
#  (u'Notes', u'text'),
#  (u'Photo', u'bytea'),
#  (u'Extension', u'character varying'),
#  (u'HomePhone', u'character varying'),
#  (u'EmployeeID', u'smallint'),
#  (u'LastName', u'character varying'),
#  (u'FirstName', u'character varying'),
#  (u'Title', u'character varying'),
#  (u'TitleOfCourtesy', u'character varying'),
#  (u'BirthDate', u'date'),
#  (u'HireDate', u'date'),
#  (u'Address', u'character varying'),
#  (u'City', u'character varying'),
#  (u'Region', u'character varying'),
#  (u'TerritoryID', u'character varying'),
#  (u'EmployeeID', u'smallint'),
#  (u'genre', u'text'),
#  (u'year', u'text'),
#  (u'title', u'text'),
#  (u'tconst', u'text'),
#  (u'rating', u'double precision'),
#  (u'num_votes', u'bigint'),
#  (u'index', u'bigint'),
#  (u'runtime', u'double precision'),
#  (u'OrderID', u'smallint'),
#  (u'Discount', u'real'),
#  (u'Quantity', u'smallint'),
#  (u'UnitPrice', u'real'),
#  (u'ProductID', u'smallint'),
#  (u'ShippedDate', u'date'),
#  (u'ShipVia', u'smallint'),
#  (u'OrderID', u'smallint'),
#  (u'ShipRegion', u'character varying'),
#  (u'ShipCity', u'character varying'),
#  (u'ShipAddress', u'character varying'),
#  (u'Freight', u'real'),
#  (u'ShipName', u'character varying'),
#  (u'ShipCountry', u'character varying'),
#  (u'ShipPostalCode', u'character varying'),
#  (u'RequiredDate', u'date'),
#  (u'OrderDate', u'date'),
#  (u'EmployeeID', u'smallint'),
#  (u'CustomerID', u'character'),
#  (u'UnitsInStock', u'smallint'),
#  (u'ProductID', u'smallint'),
#  (u'ProductName', u'character varying'),
#  (u'SupplierID', u'smallint'),
#  (u'CategoryID', u'smallint'),
#  (u'QuantityPerUnit', u'character varying'),
#  (u'UnitPrice', u'real'),
#  (u'UnitsOnOrder', u'smallint'),
#  (u'ReorderLevel', u'smallint'),
#  (u'Discontinued', u'integer'),
#  (u'index', u'bigint'),
#  (u'movie', u'text'),
#  (u'ratings', u'text'),
#  (u'0', u'text'),
#  (u'RegionDescription', u'character'),
#  (u'RegionID', u'smallint'),
#  (u'CompanyName', u'character varying'),
#  (u'Phone', u'character varying'),
#  (u'ShipperID', u'smallint'),
#  (u'CompanyName', u'character varying'),
#  (u'ShipperID', u'smallint'),
#  (u'Phone', u'character varying'),
#  (u'Region', u'character varying'),
#  (u'HomePage', u'text'),
#  (u'Fax', u'character varying'),
#  (u'Phone', u'character varying'),
#  (u'Country', u'character varying'),
#  (u'PostalCode', u'character varying'),
#  (u'City', u'character varying'),
#  (u'Address', u'character varying'),
#  (u'ContactTitle', u'character varying'),
#  (u'ContactName', u'character varying'),
#  (u'CompanyName', u'character varying'),
#  (u'SupplierID', u'smallint'),
#  (u'year', u'character varying'),
#  (u'num_votes', u'character varying'),
#  (u'title', u'character'),
#  (u'tconst', u'character'),
#  (u'runtime', u'character varying'),
#  (u'genre', u'character'),
#  (u'rating', u'character varying'),
#  (u'TerritoryID', u'character varying'),
#  (u'TerritoryDescription', u'character'),
#  (u'RegionID', u'smallint'),
#  (u'StateID', u'smallint'),
#  (u'StateAbbr', u'character varying'),
#  (u'StateName', u'character varying'),
#  (u'StateRegion', u'character varying')]

# %% [markdown]
# ### 1.c: Table peek
#
# Another way of quickly looking at table information is to query the first few rows. Do this for a couple of tables, for example: `orders`, `products`, `usstates`. Display only the first 3 rows.

# %%
# %%sql
# SELECT *
# FROM orders
# LIMIT 3
# Out:
# 3 rows affected.
# [(10248, u'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, u'Vins et alcools Chevalier', u"59 rue de l'Abbaye", u'Reims', None, u'51100', u'France'),
#  (10249, u'TOMSP', 6, datetime.date(1996, 7, 5), datetime.date(1996, 8, 16), datetime.date(1996, 7, 10), 1, 11.61, u'Toms Spezialit\xe4ten', u'Luisenstr. 48', u'M\xfcnster', None, u'44087', u'Germany'),
#  (10250, u'HANAR', 4, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 12), 2, 65.83, u'Hanari Carnes', u'Rua do Pa\xe7o, 67', u'Rio de Janeiro', u'RJ', u'05454-876', u'Brazil')]

# %% [markdown]
# As you can see, some tables (like `usstates` or `region`) contain information that is probably less prone to change than other tables (like `orders` or `order_details`). This database is well organized to avoid unnecessary duplication. Let's start digging deeper in the data.

# %% [markdown]
# ## 2: Products
#
# What products is this company selling? The `products` and `categories` tables contain information to answer this question.
#
# Use a combination of SQL queries and Pandas merge to answer the following questions:
#
# - What categories of products is the company selling?
# - How many products per category does the catalog contain?
# - Let's focus only on products that have not been discontinued => how many products per category?
# - What are the most expensive 5 products (not discontinued)?
# - How many units of each of these 5 products are there in stock?
# - Draw a pie chart of the categories, with slices that have the size of the number of products in that category (use non discontinued products)

# %% [markdown]
# ### 2.a: What categories of products is the company selling?
#
# Remember that PostgreSQL is case sensitive.

# %%
# %%sql
# SELECT DISTINCT "CategoryID", "CategoryName"
# FROM categoriesmerged
# Out:
# 8 rows affected.
# [(8L, u'Seafood'),
#  (4L, u'Dairy Products'),
#  (2L, u'Condiments'),
#  (5L, u'Grains/Cereals'),
#  (3L, u'Confections'),
#  (1L, u'Beverages'),
#  (6L, u'Meat/Poultry'),
#  (7L, u'Produce')]

# %%
# %%sql
# SELECT * FROM categoriesmerged
# Out:
# 77 rows affected.
# [(0L, 1L, u'Chai', 8L, 1L, u'10 boxes x 30 bags', 18.0, 39L, 0L, 10L, 1L, u'Beverages', u'Soft drinks, coffees, teas, beers, and ales', u'\\x'),
#  (1L, 2L, u'Chang', 1L, 1L, u'24 - 12 oz bottles', 19.0, 17L, 40L, 25L, 1L, u'Beverages', u'Soft drinks, coffees, teas, beers, and ales', u'\\x'),
#  (2L, 3L, u'Aniseed Syrup', 1L, 2L, u'12 - 550 ml bottles', 10.0, 13L, 70L, 25L, 0L, u'Condiments', u'Sweet and savory sauces, relishes, spreads, and seasonings', u'\\x'),
#  (3L, 4L, u"Chef Anton's Cajun Seasoning", 2L, 2L, u'48 - 6 oz jars', 22.0, 53L, 0L, 0L, 0L, u'Condiments', u'Sweet and savory sauces, relishes, spreads, and seasonings', u'\\x'),
#  (4L, 5L, u"Chef Anton's Gumbo Mix", 2L, 2L, u'36 boxes', 21.35, 0L, 0L, 0L, 1L, u'Condiments', u'Sweet and savory sauces, relishes, spreads, and seasonings', u'\\x'),
#  (5L, 6L, u"Grandma's Boysenberry Spread", 3L, 2L, u'12 - 8 oz jars', 25.0, 120L, 0L, 25L, 0L, u'Condiments', u'Sweet and savory sauces, relishes, spreads, and seasonings', u'\\x'),
#  (6L, 7L, u"Uncle Bob's Organic Dried Pears", 3L, 7L, u'12 - 1 lb pkgs.', 30.0, 15L, 0L, 10L, 0L, u'Produce', u'Dried fruit and bean curd', u'\\x'),
#  (7L, 8L, u'Northwoods Cranberry Sauce', 3L, 2L, u'12 - 12 oz jars', 40.0, 6L, 0L, 0L, 0L, u'Condiments', u'Sweet and savory sauces, relishes, spreads, and seasonings', u'\\x'),
#  (8L, 9L, u'Mishi Kobe Niku', 4L, 6L, u'18 - 500 g pkgs.', 97.0, 29L, 0L, 0L, 1L, u'Meat/Poultry', u'Prepared meats', u'\\x'),
#  (9L, 10L, u'Ikura', 4L, 8L, u'12 - 200 ml jars', 31.0, 31L, 0L, 0L, 0L, u'Seafood', u'Seaweed and fish', u'\\x'),
#  (10L, 11L, u'Queso Cabrales', 5L, 4L, u'1 kg pkg.', 21.0, 22L, 30L, 30L, 0L, u'Dairy Products', u'Cheeses', u'\\x'),
#  (11L, 12L, u'Queso Manchego La Pastora', 5L, 4L, u'10 - 500 g pkgs.', 38.0, 86L, 0L, 0L, 0L, u'Dairy Products', u'Cheeses', u'\\x'),
#  (12L, 13L, u'Konbu', 6L, 8L, u'2 kg box', 6.0, 24L, 0L, 5L, 0L, u'Seafood', u'Seaweed and fish', u'\\x'),
#  (13L, 14L, u'Tofu', 6L, 7L, u'40 - 100 g pkgs.', 23.25, 35L, 0L, 0L, 0L, u'Produce', u'Dried fruit and bean curd', u'\\x'),
#  (14L, 15L, u'Genen Shouyu', 6L, 2L, u'24 - 250 ml bottles', 13.0, 39L, 0L, 5L, 0L, u'Condiments', u'Sweet and savory sauces, relishes, spreads, and seasonings', u'\\x'),
#  (15L, 16L, u'Pavlova', 7L, 3L, u'32 - 500 g boxes', 17.45, 29L, 0L, 10L, 0L, u'Confections', u'Desserts, candies, and sweet breads', u'\\x'),
#  (16L, 17L, u'Alice Mutton', 7L, 6L, u'20 - 1 kg tins', 39.0, 0L, 0L, 0L, 1L, u'Meat/Poultry', u'Prepared meats', u'\\x'),
#  (17L, 18L, u'Carnarvon Tigers', 7L, 8L, u'16 kg pkg.', 62.5, 42L, 0L, 0L, 0L, u'Seafood', u'Seaweed and fish', u'\\x'),
#  (18L, 19L, u'Teatime Chocolate Biscuits', 8L, 3L, u'10 boxes x 12 pieces', 9.2, 25L, 0L, 5L, 0L, u'Confections', u'Desserts, candies, and sweet breads', u'\\x'),
#  (19L, 20L, u"Sir Rodney's Marmalade", 8L, 3L, u'30 gift boxes', 81.0, 40L, 0L, 0L, 0L, u'Confections', u'Desserts, candies, and sweet breads', u'\\x'),
#  (20L, 21L, u"Sir Rodney's Scones", 8L, 3L, u'24 pkgs. x 4 pieces', 10.0, 3L, 40L, 5L, 0L, u'Confections', u'Desserts, candies, and sweet breads', u'\\x'),
#  (21L, 22L, u"Gustaf's Kn\xe4ckebr\xf6d", 9L, 5L, u'24 - 500 g pkgs.', 21.0, 104L, 0L, 25L, 0L, u'Grains/Cereals', u'Breads, crackers, pasta, and cereal', u'\\x'),
#  (22L, 23L, u'Tunnbr\xf6d', 9L, 5L, u'12 - 250 g pkgs.', 9.0, 61L, 0L, 25L, 0L, u'Grains/Cereals', u'Breads, crackers, pasta, and cereal', u'\\x'),
#  (23L, 24L, u'Guaran\xe1 Fant\xe1stica', 10L, 1L, u'12 - 355 ml cans', 4.5, 20L, 0L, 0L, 1L, u'Beverages', u'Soft drinks, coffees, teas, beers, and ales', u'\\x'),
#  (24L, 25L, u'NuNuCa Nu\xdf-Nougat-Creme', 11L, 3L, u'20 - 450 g glasses', 14.0, 76L, 0L, 30L, 0L, u'Confections', u'Desserts, candies, and sweet breads', u'\\x'),
#  (25L, 26L, u'Gumb\xe4r Gummib\xe4rchen', 11L, 3L, u'100 - 250 g bags', 31.23, 15L, 0L, 0L, 0L, u'Confections', u'Desserts, candies, and sweet breads', u'\\x'),
#  (26L, 27L, u'Schoggi Schokolade', 11L, 3L, u'100 - 100 g pieces', 43.9, 49L, 0L, 30L, 0L, u'Confections', u'Desserts, candies, and sweet breads', u'\\x'),
#  (27L, 28L, u'R\xf6ssle Sauerkraut', 12L, 7L, u'25 - 825 g cans', 45.6, 26L, 0L, 0L, 1L, u'Produce', u'Dried fruit and bean curd', u'\\x'),
#  (28L, 29L, u'Th\xfcringer Rostbratwurst', 12L, 6L, u'50 bags x 30 sausgs.', 123.79, 0L, 0L, 0L, 1L, u'Meat/Poultry', u'Prepared meats', u'\\x'),
#  (29L, 30L, u'Nord-Ost Matjeshering', 13L, 8L, u'10 - 200 g glasses', 25.89, 10L, 0L, 15L, 0L, u'Seafood', u'Seaweed and fish', u'\\x'),
#  (30L, 31L, u'Gorgonzola Telino', 14L, 4L, u'12 - 100 g pkgs', 12.5, 0L, 70L, 20L, 0L, u'Dairy Products', u'Cheeses', u'\\x'),
#  (31L, 32L, u'Mascarpone Fabioli', 14L, 4L, u'24 - 200 g pkgs.', 32.0, 9L, 40L, 25L, 0L, u'Dairy Products', u'Cheeses', u'\\x'),
#  (32L, 33L, u'Geitost', 15L, 4L, u'500 g', 2.5, 112L, 0L, 20L, 0L, u'Dairy Products', u'Cheeses', u'\\x'),
#  (33L, 34L, u'Sasquatch Ale', 16L, 1L, u'24 - 12 oz bottles', 14.0, 111L, 0L, 15L, 0L, u'Beverages', u'Soft drinks, coffees, teas, beers, and ales', u'\\x'),
#  (34L, 35L, u'Steeleye Stout', 16L, 1L, u'24 - 12 oz bottles', 18.0, 20L, 0L, 15L, 0L, u'Beverages', u'Soft drinks, coffees, teas, beers, and ales', u'\\x'),
#  (35L, 36L, u'Inlagd Sill', 17L, 8L, u'24 - 250 g  jars', 19.0, 112L, 0L, 20L, 0L, u'Seafood', u'Seaweed and fish', u'\\x'),
#  (36L, 37L, u'Gravad lax', 17L, 8L, u'12 - 500 g pkgs.', 26.0, 11L, 50L, 25L, 0L, u'Seafood', u'Seaweed and fish', u'\\x'),
#  (37L, 38L, u'C\xf4te de Blaye', 18L, 1L, u'12 - 75 cl bottles', 263.5, 17L, 0L, 15L, 0L, u'Beverages', u'Soft drinks, coffees, teas, beers, and ales', u'\\x'),
#  (38L, 39L, u'Chartreuse verte', 18L, 1L, u'750 cc per bottle', 18.0, 69L, 0L, 5L, 0L, u'Beverages', u'Soft drinks, coffees, teas, beers, and ales', u'\\x'),
#  (39L, 40L, u'Boston Crab Meat', 19L, 8L, u'24 - 4 oz tins', 18.4, 123L, 0L, 30L, 0L, u'Seafood', u'Seaweed and fish', u'\\x'),
#  (40L, 41L, u"Jack's New England Clam Chowder", 19L, 8L, u'12 - 12 oz cans', 9.65, 85L, 0L, 10L, 0L, u'Seafood', u'Seaweed and fish', u'\\x'),
#  (41L, 42L, u'Singaporean Hokkien Fried Mee', 20L, 5L, u'32 - 1 kg pkgs.', 14.0, 26L, 0L, 0L, 1L, u'Grains/Cereals', u'Breads, crackers, pasta, and cereal', u'\\x'),
#  (42L, 43L, u'Ipoh Coffee', 20L, 1L, u'16 - 500 g tins', 46.0, 17L, 10L, 25L, 0L, u'Beverages', u'Soft drinks, coffees, teas, beers, and ales', u'\\x'),
#  (43L, 44L, u'Gula Malacca', 20L, 2L, u'20 - 2 kg bags', 19.45, 27L, 0L, 15L, 0L, u'Condiments', u'Sweet and savory sauces, relishes, spreads, and seasonings', u'\\x'),
#  (44L, 45L, u'Rogede sild', 21L, 8L, u'1k pkg.', 9.5, 5L, 70L, 15L, 0L, u'Seafood', u'Seaweed and fish', u'\\x'),
#  (45L, 46L, u'Spegesild', 21L, 8L, u'4 - 450 g glasses', 12.0, 95L, 0L, 0L, 0L, u'Seafood', u'Seaweed and fish', u'\\x'),
#  (46L, 47L, u'Zaanse koeken', 22L, 3L, u'10 - 4 oz boxes', 9.5, 36L, 0L, 0L, 0L, u'Confections', u'Desserts, candies, and sweet breads', u'\\x'),
#  (47L, 48L, u'Chocolade', 22L, 3L, u'10 pkgs.', 12.75, 15L, 70L, 25L, 0L, u'Confections', u'Desserts, candies, and sweet breads', u'\\x'),
#  (48L, 49L, u'Maxilaku', 23L, 3L, u'24 - 50 g pkgs.', 20.0, 10L, 60L, 15L, 0L, u'Confections', u'Desserts, candies, and sweet breads', u'\\x'),
#  (49L, 50L, u'Valkoinen suklaa', 23L, 3L, u'12 - 100 g bars', 16.25, 65L, 0L, 30L, 0L, u'Confections', u'Desserts, candies, and sweet breads', u'\\x'),
#  (50L, 51L, u'Manjimup Dried Apples', 24L, 7L, u'50 - 300 g pkgs.', 53.0, 20L, 0L, 10L, 0L, u'Produce', u'Dried fruit and bean curd', u'\\x'),
#  (51L, 52L, u'Filo Mix', 24L, 5L, u'16 - 2 kg boxes', 7.0, 38L, 0L, 25L, 0L, u'Grains/Cereals', u'Breads, crackers, pasta, and cereal', u'\\x'),
#  (52L, 53L, u'Perth Pasties', 24L, 6L, u'48 pieces', 32.8, 0L, 0L, 0L, 1L, u'Meat/Poultry', u'Prepared meats', u'\\x'),
#  (53L, 54L, u'Tourti\xe8re', 25L, 6L, u'16 pies', 7.45, 21L, 0L, 10L, 0L, u'Meat/Poultry', u'Prepared meats', u'\\x'),
#  (54L, 55L, u'P\xe2t\xe9 chinois', 25L, 6L, u'24 boxes x 2 pies', 24.0, 115L, 0L, 20L, 0L, u'Meat/Poultry', u'Prepared meats', u'\\x'),
#  (55L, 56L, u'Gnocchi di nonna Alice', 26L, 5L, u'24 - 250 g pkgs.', 38.0, 21L, 10L, 30L, 0L, u'Grains/Cereals', u'Breads, crackers, pasta, and cereal', u'\\x'),
#  (56L, 57L, u'Ravioli Angelo', 26L, 5L, u'24 - 250 g pkgs.', 19.5, 36L, 0L, 20L, 0L, u'Grains/Cereals', u'Breads, crackers, pasta, and cereal', u'\\x'),
#  (57L, 58L, u'Escargots de Bourgogne', 27L, 8L, u'24 pieces', 13.25, 62L, 0L, 20L, 0L, u'Seafood', u'Seaweed and fish', u'\\x'),
#  (58L, 59L, u'Raclette Courdavault', 28L, 4L, u'5 kg pkg.', 55.0, 79L, 0L, 0L, 0L, u'Dairy Products', u'Cheeses', u'\\x'),
#  (59L, 60L, u'Camembert Pierrot', 28L, 4L, u'15 - 300 g rounds', 34.0, 19L, 0L, 0L, 0L, u'Dairy Products', u'Cheeses', u'\\x'),
#  (60L, 61L, u"Sirop d'\xe9rable", 29L, 2L, u'24 - 500 ml bottles', 28.5, 113L, 0L, 25L, 0L, u'Condiments', u'Sweet and savory sauces, relishes, spreads, and seasonings', u'\\x'),
#  (61L, 62L, u'Tarte au sucre', 29L, 3L, u'48 pies', 49.3, 17L, 0L, 0L, 0L, u'Confections', u'Desserts, candies, and sweet breads', u'\\x'),
#  (62L, 63L, u'Vegie-spread', 7L, 2L, u'15 - 625 g jars', 43.9, 24L, 0L, 5L, 0L, u'Condiments', u'Sweet and savory sauces, relishes, spreads, and seasonings', u'\\x'),
#  (63L, 64L, u'Wimmers gute Semmelkn\xf6del', 12L, 5L, u'20 bags x 4 pieces', 33.25, 22L, 80L, 30L, 0L, u'Grains/Cereals', u'Breads, crackers, pasta, and cereal', u'\\x'),
#  (64L, 65L, u'Louisiana Fiery Hot Pepper Sauce', 2L, 2L, u'32 - 8 oz bottles', 21.05, 76L, 0L, 0L, 0L, u'Condiments', u'Sweet and savory sauces, relishes, spreads, and seasonings', u'\\x'),
#  (65L, 66L, u'Louisiana Hot Spiced Okra', 2L, 2L, u'24 - 8 oz jars', 17.0, 4L, 100L, 20L, 0L, u'Condiments', u'Sweet and savory sauces, relishes, spreads, and seasonings', u'\\x'),
#  (66L, 67L, u'Laughing Lumberjack Lager', 16L, 1L, u'24 - 12 oz bottles', 14.0, 52L, 0L, 10L, 0L, u'Beverages', u'Soft drinks, coffees, teas, beers, and ales', u'\\x'),
#  (67L, 68L, u'Scottish Longbreads', 8L, 3L, u'10 boxes x 8 pieces', 12.5, 6L, 10L, 15L, 0L, u'Confections', u'Desserts, candies, and sweet breads', u'\\x'),
#  (68L, 69L, u'Gudbrandsdalsost', 15L, 4L, u'10 kg pkg.', 36.0, 26L, 0L, 15L, 0L, u'Dairy Products', u'Cheeses', u'\\x'),
#  (69L, 70L, u'Outback Lager', 7L, 1L, u'24 - 355 ml bottles', 15.0, 15L, 10L, 30L, 0L, u'Beverages', u'Soft drinks, coffees, teas, beers, and ales', u'\\x'),
#  (70L, 71L, u'Flotemysost', 15L, 4L, u'10 - 500 g pkgs.', 21.5, 26L, 0L, 0L, 0L, u'Dairy Products', u'Cheeses', u'\\x'),
#  (71L, 72L, u'Mozzarella di Giovanni', 14L, 4L, u'24 - 200 g pkgs.', 34.8, 14L, 0L, 0L, 0L, u'Dairy Products', u'Cheeses', u'\\x'),
#  (72L, 73L, u'R\xf6d Kaviar', 17L, 8L, u'24 - 150 g jars', 15.0, 101L, 0L, 5L, 0L, u'Seafood', u'Seaweed and fish', u'\\x'),
#  (73L, 74L, u'Longlife Tofu', 4L, 7L, u'5 kg pkg.', 10.0, 4L, 20L, 5L, 0L, u'Produce', u'Dried fruit and bean curd', u'\\x'),
#  (74L, 75L, u'Rh\xf6nbr\xe4u Klosterbier', 12L, 1L, u'24 - 0.5 l bottles', 7.75, 125L, 0L, 25L, 0L, u'Beverages', u'Soft drinks, coffees, teas, beers, and ales', u'\\x'),
#  (75L, 76L, u'Lakkalik\xf6\xf6ri', 23L, 1L, u'500 ml', 18.0, 57L, 0L, 20L, 0L, u'Beverages', u'Soft drinks, coffees, teas, beers, and ales', u'\\x'),
#  (76L, 77L, u'Original Frankfurter gr\xfcne So\xdfe', 12L, 2L, u'12 boxes', 13.0, 32L, 0L, 15L, 0L, u'Condiments', u'Sweet and savory sauces, relishes, spreads, and seasonings', u'\\x')]

# %% [markdown]
# ### 2.b: How many products per category does the catalog contain?
#
# Keep in mind that you can cast a %sql result to a pandas dataframe using the `.DataFrame()` method.

# %% [markdown]
# ### 2.c: How many not discontinued products per category?

# %% [markdown]
# ### 2.d: What are the most expensive 5 products (not discontinued)?

# %% [markdown]
# ### 2.e: How many units of each of these 5 products are there in stock?

# %% [markdown]
# ### 2.f: Pie Chart
#
# Use pandas to make a pie chart plot.

# %% [markdown]
# ## 3: Orders
#
# Now that we have a better understanding of products, let's start digging into orders.
#
# - How many orders in total?
# - How many orders per year
# - How many orders per quarter
# - Which country is receiving the most orders
# - Which country is receiving the least
# - What's the average shipping time (ShippedDate - OrderDate)
# - What customer is submitting the highest number of orders?
# - What customer is generating the highest revenue (need to pd.merge with order_details)
# - What fraction of the revenue is generated by the top 5 customers?

# %% [markdown]
# ### 3.a: How many orders in total?

# %% [markdown]
# ### 3.b: How many orders per year?

# %% [markdown]
# ### 3.c: How many orders per quarter?
#
# Make a line plot for these.

# %% [markdown]
# ### 3.d: Which country is receiving the most orders?

# %% [markdown]
# ### 3.e: Which country is receiving the least?

# %% [markdown]
# ### 3.f: What's the average shipping time (ShippedDate - OrderDate)?

# %% [markdown]
# ### 3.g: What customer is submitting the highest number of orders?

# %% [markdown]
# ### 3.h: What customer is generating the highest revenue (need to pd.merge with order_details)?

# %% [markdown]
# ### 3.i: What fraction of the revenue is generated by the top 5 customers?
#
# Compare that with the fraction represented by 5 customers over the total number of customers.

# %% [markdown]
# Wow!! 5.5% of the customers generate a third of the revenue!!

# %% [markdown]
# ## Bonus: Other tables
#
# Investigate the content of other tables. In particular lookt at the `suppliers`, `shippers` and `employees` tables.
