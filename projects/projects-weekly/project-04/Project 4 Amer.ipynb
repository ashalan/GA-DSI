# %%
import pandas as pd
import numpy as np
cities=pd.read_csv("Data/Living_Index.csv")
nyse=pd.read_csv("Data/NYSE.csv")
nasdaq=pd.read_csv("Data/NASDAQ.csv")
amex=pd.read_csv("Data/AMEX.csv")
stocks=nyse.append(nasdaq,ignore_index=True).append(amex,ignore_index=True)
cities=cities.rename(columns={"Urban Area":"City"})
city_list=[x for x in cities['City']]

# %%
salaries = pd.read_json("Data/allcities.json")

# %%
len(salaries)
# Out:
# 1546

# %%
def only_numerics(seq):
    seq = seq.split('-')
    try:
        out = ((int(filter(type(seq[0]).isdigit, seq[0])) + int(filter(type(seq[1]).isdigit, seq[1])))/2)*1000
    except:
        out = int(filter(type(seq[0]).isdigit, seq[0]))
    return out

salaries['meanPay'] = salaries['meanPay'].apply(only_numerics)

# %%
salaries = salaries[salaries.jobTitle.str.contains("Intern") == False]
salaries = salaries[salaries.jobTitle.str.contains("Hourly") == False]
salaries['jobTitle'].unique()
# Out:
# array([u'Data Scientist', u'Entry Level Data Scientist',
#        u'Senior Data Scientist', u'Junior Data Scientist',
#        u'Principal Data Scientist', u'Data Scientist II',
#        u'Data Scientist I', u'Associate Data Scientist',
#        u'Chief Data Scientist',
#        u'Clinical Laboratory Scientist-data Analyst',
#        u'Senior Data Scientist/Statistician',
#        u'Scientist, Statistical and Data Sciences',
#        u'Data Visualization Scientist', u'Staff Data Scientist',
#        u'Lead Data Scientist', u'Software Engineer (Data Scientist)'], dtype=object)

# %%
salaries['state'] = salaries.city.apply(lambda x: x[-2:])
salaries.head()
# Out:
#             city     company        jobTitle  meanPay state
# 0     Albany, NY          GE  Data Scientist   104000    NY
# 1  Arlington, TX  State Farm  Data Scientist   105000    TX
# 2  Arlington, TX     Epsilon  Data Scientist   166000    TX
# 3  Arlington, TX       Match  Data Scientist    82000    TX
# 4  Arlington, TX        Hudl  Data Scientist    90000    TX

# %% [markdown]
# Remove duplicates:

# %%
cities = salaries.groupby(['city', 'state'])['city'].count().to_frame()

# %%
cities.rename(columns={'city': 'count'}, inplace=True)
cities.reset_index(inplace=True)

# %%
cities['duplicated'] = cities.duplicated(['count', 'state'], keep=False)

# %%
cities[cities['duplicated']==True].sort_values(by=['state','count'])
# Out:
#                  city state  count duplicated
# 55        Oakland, CA    CA    134       True
# 75  San Francisco, CA    CA    134       True
# 9       Bradenton, FL    FL      1       True
# 78       Sarasota, FL    FL      1       True
# 2         Atlanta, GA    GA     42       True
# 48       Marietta, GA    GA     42       True
# 6     Baton Rouge, LA    LA      2       True
# 36        Hammond, LA    LA      2       True
# 45      Lafayette, LA    LA      2       True
# 50    Minneapolis, MN    MN     11       True
# 82       St. Paul, MN    MN     11       True
# 12    Chapel Hill, NC    NC     15       True
# 29         Durham, NC    NC     15       True
# 65        Raleigh, NC    NC     15       True
# 46     Las Cruces, NM    NM      1       True
# 67     Rio Rancho, NM    NM      1       True
# 0          Albany, NY    NY      1       True
# 10        Buffalo, NY    NY      1       True
# 85       Syracuse, NY    NY      1       True
# 16     Cincinnati, OH    OH      5       True
# 17      Cleveland, OH    OH      5       True
# 11         Camden, SC    SC      1       True
# 19       Columbia, SC    SC      1       True
# 84         Sumter, SC    SC      1       True
# 44      Knoxville, TN    TN      2       True
# 52     Morristown, TN    TN      2       True
# 73    San Antonio, TX    TX      3       True
# 80         Seguin, TX    TX      3       True
# 21         Conroe, TX    TX     16       True
# 40        Houston, TX    TX     16       True
# 3          Austin, TX    TX     26       True
# 70     Round Rock, TX    TX     26       True
# 77     San Marcos, TX    TX     26       True
# 1       Arlington, TX    TX     39       True
# 24         Dallas, TX    TX     39       True
# 34     Fort Worth, TX    TX     39       True
# 61          Plano, TX    TX     39       True
# 89    Weatherford, TX    TX     39       True
# 30        Everett, WA    WA     45       True
# 79        Seattle, WA    WA     45       True
# 86         Tacoma, WA    WA     45       True

# %%
# What to remove:
removables = ['Everett, WA', 'Tacoma, WA', 'Weatherford, TX', 'Plano, TX', 'Fort Worth, TX', 'Arlington, TX', 'San Marcos, TX', 'Round Rock, TX', 'Conroe, TX', 'Seguin, TX', 'Morristown, TN', 'Sumter, SC', 'Camden, SC', 'Durham, NC', 'Chapel Hill, NC', 'St. Paul, MN', 'Hammond, LA', 'Marietta, GA', 'Bradenton, FL', 'Oakland, CA']

# %%
salaries = salaries[~salaries['city'].isin(removables)]
salaries.reset_index(inplace=True)
del salaries['index']
# Out:
#                city                           company  \
# 0        Albany, NY                                GE
# 1       Atlanta, GA                     CareerBuilder
# 2       Atlanta, GA                               NCR
# 3       Atlanta, GA                    The Home Depot
# 4       Atlanta, GA                           Feedzai
# 5       Atlanta, GA                               IBM
# 6       Atlanta, GA               Booz Allen Hamilton
# 7       Atlanta, GA                               PwC
# 8       Atlanta, GA    Cognizant Technology Solutions
# 9       Atlanta, GA                 Rang Technologies
# 10      Atlanta, GA                              KPMG
# 11      Atlanta, GA                            Gallup
# 12      Atlanta, GA  Hewlett Packard Enterprise | HPE
# 13      Atlanta, GA                           Verizon
# 14      Atlanta, GA                  Verizon Wireless
# 15      Atlanta, GA                 Fractal Analytics
# 16      Atlanta, GA                           Equifax
# 17      Atlanta, GA                  Northrop Grumman
# 18      Atlanta, GA                               ADP
# 19      Atlanta, GA                           Kabbage
# 20      Atlanta, GA                              Citi
# 21      Atlanta, GA                         Honeywell
# 22      Atlanta, GA                Intuitive Surgical
# 23      Atlanta, GA                              AT&T
# 24      Atlanta, GA                   Cox Enterprises
# 25      Atlanta, GA                            Hearst
# 26      Atlanta, GA                            Macy's
# 27      Atlanta, GA                   Bank of America
# 28      Atlanta, GA                               IBM
# 29      Atlanta, GA                               IBM
# ..              ...                               ...
# 931   Vancouver, WA                            GitHub
# 932   Vancouver, WA                               CNA
# 933   Vancouver, WA                          comScore
# 934   Vancouver, WA                 Intel Corporation
# 935   Vancouver, WA   Market Strategies International
# 936   Vancouver, WA                            McAfee
# 937     Wichita, KS                           Cargill
# 938  Wilmington, DE                   Assero Services
# 939  Wilmington, DE               Booz Allen Hamilton
# 940  Wilmington, DE                           Comcast
# 941  Wilmington, DE                             Chubb
# 942  Wilmington, DE                               IBM
# 943  Wilmington, DE                       Capital One
# 944  Wilmington, DE                               PwC
# 945  Wilmington, DE    Cognizant Technology Solutions
# 946  Wilmington, DE                              KPMG
# 947  Wilmington, DE                   Lockheed Martin
# 948  Wilmington, DE                      QuintilesIMS
# 949  Wilmington, DE                            DuPont
# 950  Wilmington, DE                    Morgan Stanley
# 951  Wilmington, DE               PRA Health Sciences
# 952  Wilmington, DE                               IBM
# 953  Wilmington, DE                           Comcast
# 954  Wilmington, DE                              KPMG
# 955  Wilmington, DE                       Capital One
# 956  Wilmington, DE                               SAP
# 957  Wilmington, DE                       Capital One
# 958  Wilmington, DE                   Thomson Reuters
# 959  Wilmington, DE                           Comcast
# 960  Wilmington, DE                          Ascensus
#
#                        jobTitle  meanPay state
# 0                Data Scientist   104000    NY
# 1                Data Scientist    86172    GA
# 2                Data Scientist    89000    GA
# 3                Data Scientist    97000    GA
# 4                Data Scientist    90000    GA
# 5                Data Scientist   104000    GA
# 6                Data Scientist    75000    GA
# 7                Data Scientist    99000    GA
# 8                Data Scientist    90000    GA
# 9                Data Scientist   100000    GA
# 10               Data Scientist    93000    GA
# 11               Data Scientist    84000    GA
# 12               Data Scientist    94000    GA
# 13               Data Scientist   108000    GA
# 14               Data Scientist    99000    GA
# 15               Data Scientist    85000    GA
# 16               Data Scientist    93000    GA
# 17               Data Scientist    96000    GA
# 18               Data Scientist    88000    GA
# 19               Data Scientist    93000    GA
# 20               Data Scientist    94000    GA
# 21               Data Scientist   101000    GA
# 22               Data Scientist   111000    GA
# 23               Data Scientist   108000    GA
# 24               Data Scientist    96000    GA
# 25               Data Scientist    95000    GA
# 26               Data Scientist    89000    GA
# 27               Data Scientist    95000    GA
# 28   Entry Level Data Scientist    92000    GA
# 29        Senior Data Scientist   118000    GA
# ..                          ...      ...   ...
# 931              Data Scientist   113000    WA
# 932              Data Scientist   106000    WA
# 933              Data Scientist   101000    WA
# 934       Senior Data Scientist   128000    WA
# 935       Senior Data Scientist    97000    WA
# 936       Senior Data Scientist   126000    WA
# 937              Data Scientist    99000    KS
# 938              Data Scientist    40000    DE
# 939              Data Scientist    95000    DE
# 940              Data Scientist    71000    DE
# 941              Data Scientist   104000    DE
# 942              Data Scientist   107000    DE
# 943              Data Scientist   111000    DE
# 944              Data Scientist   101000    DE
# 945              Data Scientist    94000    DE
# 946              Data Scientist    95000    DE
# 947              Data Scientist    99000    DE
# 948              Data Scientist    98000    DE
# 949              Data Scientist   120000    DE
# 950              Data Scientist   100000    DE
# 951              Data Scientist    97000    DE
# 952  Entry Level Data Scientist    96000    DE
# 953       Senior Data Scientist   140000    DE
# 954       Senior Data Scientist   108000    DE
# 955       Senior Data Scientist   124000    DE
# 956       Senior Data Scientist    97000    DE
# 957    Principal Data Scientist   138000    DE
# 958    Principal Data Scientist   122000    DE
# 959    Principal Data Scientist   126000    DE
# 960    Associate Data Scientist    75000    DE
#
# [961 rows x 5 columns]

# %% [markdown]
# Remove state name from city

# %%
salaries['city'] = salaries.city.apply(lambda x: x[:-4])
# Out:
#            city                           company                    jobTitle  \
# 0        Albany                                GE              Data Scientist
# 1       Atlanta                     CareerBuilder              Data Scientist
# 2       Atlanta                               NCR              Data Scientist
# 3       Atlanta                    The Home Depot              Data Scientist
# 4       Atlanta                           Feedzai              Data Scientist
# 5       Atlanta                               IBM              Data Scientist
# 6       Atlanta               Booz Allen Hamilton              Data Scientist
# 7       Atlanta                               PwC              Data Scientist
# 8       Atlanta    Cognizant Technology Solutions              Data Scientist
# 9       Atlanta                 Rang Technologies              Data Scientist
# 10      Atlanta                              KPMG              Data Scientist
# 11      Atlanta                            Gallup              Data Scientist
# 12      Atlanta  Hewlett Packard Enterprise | HPE              Data Scientist
# 13      Atlanta                           Verizon              Data Scientist
# 14      Atlanta                  Verizon Wireless              Data Scientist
# 15      Atlanta                 Fractal Analytics              Data Scientist
# 16      Atlanta                           Equifax              Data Scientist
# 17      Atlanta                  Northrop Grumman              Data Scientist
# 18      Atlanta                               ADP              Data Scientist
# 19      Atlanta                           Kabbage              Data Scientist
# 20      Atlanta                              Citi              Data Scientist
# 21      Atlanta                         Honeywell              Data Scientist
# 22      Atlanta                Intuitive Surgical              Data Scientist
# 23      Atlanta                              AT&T              Data Scientist
# 24      Atlanta                   Cox Enterprises              Data Scientist
# 25      Atlanta                            Hearst              Data Scientist
# 26      Atlanta                            Macy's              Data Scientist
# 27      Atlanta                   Bank of America              Data Scientist
# 28      Atlanta                               IBM  Entry Level Data Scientist
# 29      Atlanta                               IBM       Senior Data Scientist
# ..          ...                               ...                         ...
# 931   Vancouver                            GitHub              Data Scientist
# 932   Vancouver                               CNA              Data Scientist
# 933   Vancouver                          comScore              Data Scientist
# 934   Vancouver                 Intel Corporation       Senior Data Scientist
# 935   Vancouver   Market Strategies International       Senior Data Scientist
# 936   Vancouver                            McAfee       Senior Data Scientist
# 937     Wichita                           Cargill              Data Scientist
# 938  Wilmington                   Assero Services              Data Scientist
# 939  Wilmington               Booz Allen Hamilton              Data Scientist
# 940  Wilmington                           Comcast              Data Scientist
# 941  Wilmington                             Chubb              Data Scientist
# 942  Wilmington                               IBM              Data Scientist
# 943  Wilmington                       Capital One              Data Scientist
# 944  Wilmington                               PwC              Data Scientist
# 945  Wilmington    Cognizant Technology Solutions              Data Scientist
# 946  Wilmington                              KPMG              Data Scientist
# 947  Wilmington                   Lockheed Martin              Data Scientist
# 948  Wilmington                      QuintilesIMS              Data Scientist
# 949  Wilmington                            DuPont              Data Scientist
# 950  Wilmington                    Morgan Stanley              Data Scientist
# 951  Wilmington               PRA Health Sciences              Data Scientist
# 952  Wilmington                               IBM  Entry Level Data Scientist
# 953  Wilmington                           Comcast       Senior Data Scientist
# 954  Wilmington                              KPMG       Senior Data Scientist
# 955  Wilmington                       Capital One       Senior Data Scientist
# 956  Wilmington                               SAP       Senior Data Scientist
# 957  Wilmington                       Capital One    Principal Data Scientist
# 958  Wilmington                   Thomson Reuters    Principal Data Scientist
# 959  Wilmington                           Comcast    Principal Data Scientist
# 960  Wilmington                          Ascensus    Associate Data Scientist
#
#      meanPay state
# 0     104000    NY
# 1      86172    GA
# 2      89000    GA
# 3      97000    GA
# 4      90000    GA
# 5     104000    GA
# 6      75000    GA
# 7      99000    GA
# 8      90000    GA
# 9     100000    GA
# 10     93000    GA
# 11     84000    GA
# 12     94000    GA
# 13    108000    GA
# 14     99000    GA
# 15     85000    GA
# 16     93000    GA
# 17     96000    GA
# 18     88000    GA
# 19     93000    GA
# 20     94000    GA
# 21    101000    GA
# 22    111000    GA
# 23    108000    GA
# 24     96000    GA
# 25     95000    GA
# 26     89000    GA
# 27     95000    GA
# 28     92000    GA
# 29    118000    GA
# ..       ...   ...
# 931   113000    WA
# 932   106000    WA
# 933   101000    WA
# 934   128000    WA
# 935    97000    WA
# 936   126000    WA
# 937    99000    KS
# 938    40000    DE
# 939    95000    DE
# 940    71000    DE
# 941   104000    DE
# 942   107000    DE
# 943   111000    DE
# 944   101000    DE
# 945    94000    DE
# 946    95000    DE
# 947    99000    DE
# 948    98000    DE
# 949   120000    DE
# 950   100000    DE
# 951    97000    DE
# 952    96000    DE
# 953   140000    DE
# 954   108000    DE
# 955   124000    DE
# 956    97000    DE
# 957   138000    DE
# 958   122000    DE
# 959   126000    DE
# 960    75000    DE
#
# [961 rows x 5 columns]

# %% [markdown]
# Rearrange state to be next to city

# %%
cols = ['city', 'state', 'company', 'jobTitle', 'meanPay']
salaries = salaries[cols]
salaries
# Out:
#            city state                           company  \
# 0        Albany    NY                                GE
# 1       Atlanta    GA                     CareerBuilder
# 2       Atlanta    GA                               NCR
# 3       Atlanta    GA                    The Home Depot
# 4       Atlanta    GA                           Feedzai
# 5       Atlanta    GA                               IBM
# 6       Atlanta    GA               Booz Allen Hamilton
# 7       Atlanta    GA                               PwC
# 8       Atlanta    GA    Cognizant Technology Solutions
# 9       Atlanta    GA                 Rang Technologies
# 10      Atlanta    GA                              KPMG
# 11      Atlanta    GA                            Gallup
# 12      Atlanta    GA  Hewlett Packard Enterprise | HPE
# 13      Atlanta    GA                           Verizon
# 14      Atlanta    GA                  Verizon Wireless
# 15      Atlanta    GA                 Fractal Analytics
# 16      Atlanta    GA                           Equifax
# 17      Atlanta    GA                  Northrop Grumman
# 18      Atlanta    GA                               ADP
# 19      Atlanta    GA                           Kabbage
# 20      Atlanta    GA                              Citi
# 21      Atlanta    GA                         Honeywell
# 22      Atlanta    GA                Intuitive Surgical
# 23      Atlanta    GA                              AT&T
# 24      Atlanta    GA                   Cox Enterprises
# 25      Atlanta    GA                            Hearst
# 26      Atlanta    GA                            Macy's
# 27      Atlanta    GA                   Bank of America
# 28      Atlanta    GA                               IBM
# 29      Atlanta    GA                               IBM
# ..          ...   ...                               ...
# 931   Vancouver    WA                            GitHub
# 932   Vancouver    WA                               CNA
# 933   Vancouver    WA                          comScore
# 934   Vancouver    WA                 Intel Corporation
# 935   Vancouver    WA   Market Strategies International
# 936   Vancouver    WA                            McAfee
# 937     Wichita    KS                           Cargill
# 938  Wilmington    DE                   Assero Services
# 939  Wilmington    DE               Booz Allen Hamilton
# 940  Wilmington    DE                           Comcast
# 941  Wilmington    DE                             Chubb
# 942  Wilmington    DE                               IBM
# 943  Wilmington    DE                       Capital One
# 944  Wilmington    DE                               PwC
# 945  Wilmington    DE    Cognizant Technology Solutions
# 946  Wilmington    DE                              KPMG
# 947  Wilmington    DE                   Lockheed Martin
# 948  Wilmington    DE                      QuintilesIMS
# 949  Wilmington    DE                            DuPont
# 950  Wilmington    DE                    Morgan Stanley
# 951  Wilmington    DE               PRA Health Sciences
# 952  Wilmington    DE                               IBM
# 953  Wilmington    DE                           Comcast
# 954  Wilmington    DE                              KPMG
# 955  Wilmington    DE                       Capital One
# 956  Wilmington    DE                               SAP
# 957  Wilmington    DE                       Capital One
# 958  Wilmington    DE                   Thomson Reuters
# 959  Wilmington    DE                           Comcast
# 960  Wilmington    DE                          Ascensus
#
#                        jobTitle  meanPay
# 0                Data Scientist   104000
# 1                Data Scientist    86172
# 2                Data Scientist    89000
# 3                Data Scientist    97000
# 4                Data Scientist    90000
# 5                Data Scientist   104000
# 6                Data Scientist    75000
# 7                Data Scientist    99000
# 8                Data Scientist    90000
# 9                Data Scientist   100000
# 10               Data Scientist    93000
# 11               Data Scientist    84000
# 12               Data Scientist    94000
# 13               Data Scientist   108000
# 14               Data Scientist    99000
# 15               Data Scientist    85000
# 16               Data Scientist    93000
# 17               Data Scientist    96000
# 18               Data Scientist    88000
# 19               Data Scientist    93000
# 20               Data Scientist    94000
# 21               Data Scientist   101000
# 22               Data Scientist   111000
# 23               Data Scientist   108000
# 24               Data Scientist    96000
# 25               Data Scientist    95000
# 26               Data Scientist    89000
# 27               Data Scientist    95000
# 28   Entry Level Data Scientist    92000
# 29        Senior Data Scientist   118000
# ..                          ...      ...
# 931              Data Scientist   113000
# 932              Data Scientist   106000
# 933              Data Scientist   101000
# 934       Senior Data Scientist   128000
# 935       Senior Data Scientist    97000
# 936       Senior Data Scientist   126000
# 937              Data Scientist    99000
# 938              Data Scientist    40000
# 939              Data Scientist    95000
# 940              Data Scientist    71000
# 941              Data Scientist   104000
# 942              Data Scientist   107000
# 943              Data Scientist   111000
# 944              Data Scientist   101000
# 945              Data Scientist    94000
# 946              Data Scientist    95000
# 947              Data Scientist    99000
# 948              Data Scientist    98000
# 949              Data Scientist   120000
# 950              Data Scientist   100000
# 951              Data Scientist    97000
# 952  Entry Level Data Scientist    96000
# 953       Senior Data Scientist   140000
# 954       Senior Data Scientist   108000
# 955       Senior Data Scientist   124000
# 956       Senior Data Scientist    97000
# 957    Principal Data Scientist   138000
# 958    Principal Data Scientist   122000
# 959    Principal Data Scientist   126000
# 960    Associate Data Scientist    75000
#
# [961 rows x 5 columns]
